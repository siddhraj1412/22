# %% [markdown]
# <a href="https://www.kaggle.com/code/siddhrajthakor/cat-vs-dog-image-classification-using-cnn?scriptVersionId=290108529" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # CAT VS DOG CLASIFICATION USING CNN

# %% [markdown]
# This notebook presents a Convolutional Neural Network (CNN) approach for solving the classic **Cats vs Dogs image classification** problem.
#
# The complete implementation — including data loading via Kaggle API, preprocessing, model training, and evaluation — was developed and executed in **Google Colab**.
#
# ### 🔗 Colab Notebook
# You can view the full working implementation here:
# 👉 **[Open Colab Notebook](https://colab.research.google.com/drive/1HoS5k61l2fq_8eZ7ID86hjRZHoZLdzLP?usp=sharing)**
#
# ### 🧠 Key Highlights
# - Binary image classification (Cat vs Dog)
# - CNN-based deep learning approach
# - Implemented using TensorFlow / Keras
# - Kaggle dataset accessed via Kaggle API
#
# This notebook serves as a concise reference pointing to the full implementation and workflow.
