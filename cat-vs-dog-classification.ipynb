# %% [markdown]
# <a href="https://www.kaggle.com/code/siddhrajthakor/cat-vs-dog-classification?scriptVersionId=289862423" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # CAT VS DOG CLASIFICATION USING CNN

# %% [markdown]
# # **I have done this in the Colab file using kaggle api so colab link is here**
#
#
# [Notebook](https://colab.research.google.com/drive/1HoS5k61l2fq_8eZ7ID86hjRZHoZLdzLP?usp=sharing)
